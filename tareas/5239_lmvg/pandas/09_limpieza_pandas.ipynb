# %% [markdown]
# # Prediccion de Default en Prestamos

# %% [markdown]
# Para este proyecto utilizaremos un sample de los datos de Lending Club. La idea es predecir si cierto usuario cometera Default basado en informacion que la plataforma recolecta. Esto nos ayudara a mejorar la metodologia/pipeline de prestamo.

# %% [markdown]
# # Descripcion

# %% [markdown]
# Contiene los prestamos de esta plataforma:
#
#     periodo 2007-2017Q3.
#     887mil observaciones, sample de 100mil
#     150 variables
#     Target: loan status

# %% [markdown]
# # Objetivo

# %% [markdown]
# Realizar un ETL y un EDA

# %% [markdown]
# ## ETL

# %% [markdown]
# 0. Limpia los datos de tal manera que al final del ETL queden en formato `tidy`.
# 1. Asegurate de cargar y leer los datos
# 2. Crea una tabla donde se guarde el nombre de la columna y el tipo de dato: (`column_name`,   `type`).
# 3. Asegurate de pensar cual es el tipo de dato correcto. Porque elejiste strig/object o float o int?. No hay respuestas incorrectas como tal, pero tienes que justificar tu decision.
# 4. Maneja missings o nans de la manera adecuada. Justifica cada decision

# %% [markdown]
# ## EDA

# %% [markdown]
# 0. Preparar lo datos para un pipeline de datos
# 1. Quitar columnas inservibles
# 2. Imputar valores
# 3. Mantener replicabildiad y reproducibilidad

# %% [markdown]
# **No olvides anotar tus justificaciones en celdas para recordar cuando te toque explicarlo.** Puedes agregar el numero de celdas que necesites para poner tu explicacion y el codigo, solo manten la estructura.

# %% [markdown]
# # ETL

# %%
import pandas as pd
import numpy as np
import gzip
import openpyxl
import pickle

from io import StringIO
import requests

# %% [markdown]
# Vas a obtener 2 errores, solucionalo con los visto en clase.
# Tip: Se arreglan con argumentos adicionales de la funcion `read_csv`
# Documentacion: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html

# %%
# URL del archivo CSV comprimido en formato Gzip
url = 'https://github.com/sonder-art/fdd_prim_2023/blob/main/codigo/pandas/LoansData_sample.csv.gz?raw=true'

# Descargar el archivo comprimido en formato Gzip
response = requests.get(url)
data = gzip.decompress(response.content).decode('utf-8')

# Crear un objeto StringIO para leer el CSV con pandas
loans = pd.read_csv(StringIO(data))

loans
# Out:
# /var/folders/7r/6s1q_b2x7rldv60cty2jvx440000gn/T/ipykernel_4389/2817855808.py:9: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   loans = pd.read_csv(StringIO(data))
#        Unnamed: 0        id  member_id  loan_amnt  funded_amnt  \
# 0               0  38098114        NaN    15000.0      15000.0
# 1               1  36805548        NaN    10400.0      10400.0
# 2               2  37842129        NaN    21425.0      21425.0
# 3               3  37612354        NaN    12800.0      12800.0
# 4               4  37662224        NaN     7650.0       7650.0
# ...           ...       ...        ...        ...          ...
# 99995       99995  22454240        NaN     8400.0       8400.0
# 99996       99996  11396920        NaN    10000.0      10000.0
# 99997       99997   8556176        NaN    30000.0      30000.0
# 99998       99998  24023408        NaN     8475.0       8475.0
# 99999       99999  24023398        NaN    25000.0      25000.0
#
#        funded_amnt_inv        term  int_rate  installment grade  ...  \
# 0              15000.0   60 months     12.39       336.64     C  ...
# 1              10400.0   36 months      6.99       321.08     A  ...
# 2              21425.0   60 months     15.59       516.36     D  ...
# 3              12800.0   60 months     17.14       319.08     D  ...
# 4               7650.0   36 months     13.66       260.20     C  ...
# ...                ...         ...       ...          ...   ...  ...
# 99995           8400.0   36 months      9.17       267.79     B  ...
# 99996          10000.0   36 months     12.99       336.90     C  ...
# 99997          30000.0   60 months     20.99       811.44     E  ...
# 99998           8475.0   36 months     24.99       336.92     F  ...
# 99999          25000.0   36 months     10.15       808.45     B  ...
#
#       hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN
# ...                              ...                          ...
# 99995                            NaN                          NaN
# 99996                            NaN                          NaN
# 99997                            NaN                          NaN
# 99998                            NaN                          NaN
# 99999                            NaN                          NaN
#
#       disbursement_method debt_settlement_flag  debt_settlement_flag_date  \
# 0                    Cash                    N                        NaN
# 1                    Cash                    N                        NaN
# 2                    Cash                    N                        NaN
# 3                    Cash                    N                        NaN
# 4                    Cash                    N                        NaN
# ...                   ...                  ...                        ...
# 99995                Cash                    N                        NaN
# 99996                Cash                    N                        NaN
# 99997                Cash                    N                        NaN
# 99998                Cash                    N                        NaN
# 99999                Cash                    N                        NaN
#
#       settlement_status settlement_date settlement_amount  \
# 0                   NaN             NaN               NaN
# 1                   NaN             NaN               NaN
# 2                   NaN             NaN               NaN
# 3                   NaN             NaN               NaN
# 4                   NaN             NaN               NaN
# ...                 ...             ...               ...
# 99995               NaN             NaN               NaN
# 99996               NaN             NaN               NaN
# 99997               NaN             NaN               NaN
# 99998               NaN             NaN               NaN
# 99999               NaN             NaN               NaN
#
#       settlement_percentage settlement_term
# 0                       NaN             NaN
# 1                       NaN             NaN
# 2                       NaN             NaN
# 3                       NaN             NaN
# 4                       NaN             NaN
# ...                     ...             ...
# 99995                   NaN             NaN
# 99996                   NaN             NaN
# 99997                   NaN             NaN
# 99998                   NaN             NaN
# 99999                   NaN             NaN
#
# [100000 rows x 151 columns]

# %% [markdown]
# ## Tabla (column_name, type)

# %% [markdown]
# Revisa el metodo pd.DataFrame.dtypes. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dtypes.html

# %%
column_types = loans.dtypes
column_types
# Out:
# Unnamed: 0                 int64
# id                         int64
# member_id                float64
# loan_amnt                float64
# funded_amnt              float64
#                           ...
# settlement_status         object
# settlement_date           object
# settlement_amount        float64
# settlement_percentage    float64
# settlement_term          float64
# Length: 151, dtype: object

# %% [markdown]
# ## Cargar descripcion de columnas

# %% [markdown]
# La siguiente tabla tiene una descripcion del significado de cada columna

# %%
import pandas as pd
import requests
from io import BytesIO

# URL del archivo Excel
url = 'https://resources.lendingclub.com/LCDataDictionary.xlsx'

# Descargar el archivo
response = requests.get(url)

# Verificar si la descarga fue exitosa
if response.status_code == 200:
    # Leer el contenido del archivo descargado
    content = response.content
    # Convertir el contenido a un objeto BytesIO
    excel_data = BytesIO(content)
    # Leer el archivo Excel desde el objeto BytesIO
    datos_dict = pd.read_excel(excel_data)
    # Ahora puedes seguir utilizando los datos cargados
    datos_dict.columns = ['feature', 'description']
else:
    print("No se pudo descargar el archivo.")

# Hacer uso de los datos cargados

# %%
datos_dict
# Out:
#                    feature                                        description
# 0           acc_now_delinq  The number of accounts on which the borrower i...
# 1     acc_open_past_24mths         Number of trades opened in past 24 months.
# 2               addr_state  The state provided by the borrower in the loan...
# 3                 all_util              Balance to credit limit on all trades
# 4               annual_inc  The self-reported annual income provided by th...
# ..                     ...                                                ...
# 148      settlement_amount  The loan amount that the borrower has agreed t...
# 149  settlement_percentage  The settlement amount as a percentage of the p...
# 150        settlement_term  The number of months that the borrower will be...
# 151                    NaN                                                NaN
# 152                    NaN  * Employer Title replaces Employer Name for al...
#
# [153 rows x 2 columns]

# %% [markdown]
# ### Pickle

# %% [markdown]
# Crea codigo para **guardar** y **cargar** el DataFrame de `datos_dict` creada en las celdas anteriores en formato **pickle**

# %%
# Codigo guardar
with open('datos_dict.pkl', 'wb') as f:
    pickle.dump(datos_dict, f)

# %%
# Codigo para cargar
with open('datos_dict.pkl', 'rb') as f:
    loaded_df = pickle.load(f)

loaded_df
# Out:
#                    feature                                        description
# 0           acc_now_delinq  The number of accounts on which the borrower i...
# 1     acc_open_past_24mths         Number of trades opened in past 24 months.
# 2               addr_state  The state provided by the borrower in the loan...
# 3                 all_util              Balance to credit limit on all trades
# 4               annual_inc  The self-reported annual income provided by th...
# ..                     ...                                                ...
# 148      settlement_amount  The loan amount that the borrower has agreed t...
# 149  settlement_percentage  The settlement amount as a percentage of the p...
# 150        settlement_term  The number of months that the borrower will be...
# 151                    NaN                                                NaN
# 152                    NaN  * Employer Title replaces Employer Name for al...
#
# [153 rows x 2 columns]

# %% [markdown]
# ## Tipos de Datos

# %% [markdown]
# Realiza las transformaciones o casteos (casting) que creas necesarios a tus datos de tal manera que el typo de dato sea adecuado. Al terminar recrea la tabla `column_types` con los nuevos tipos.

# %% [markdown]
# No olvides anotar tus justificaciones para recordar cuando te toque explicarlo.

# %%
# Manejos de tipos 1
def convert_column_type(column):
    # Comprueba si todos los valores en la columna son cadenas (str)
    if all(isinstance(value, str) for value in column):
        return column  # Si todos son cadenas, devuelve la columna sin cambios

    # Intenta convertir la columna a tipo entero (int)
    try:
        column_as_int = pd.to_numeric(column, errors='raise', downcast='integer')
        # Comprueba si la columna convertida a entero es igual a la columna original
        if column_as_int.equals(column):
            return column_as_int  # Si son iguales, devuelve la columna convertida a entero
    except (ValueError, TypeError):
        pass  # Si hay un error al convertir, continúa con la siguiente conversión

    # Intenta convertir la columna a tipo flotante (float)
    try:
        column_as_float = pd.to_numeric(column, errors='raise', downcast='float')
        # Comprueba si la columna convertida a flotante es igual a la columna original
        if column_as_float.equals(column):
            return column_as_float  # Si son iguales, devuelve la columna convertida a flotante
    except (ValueError, TypeError):
        pass  # Si hay un error al convertir, devuelve la columna original

    # Si no se ha realizado ninguna conversión, devuelve la columna original
    return column

# %%
# Manejos de tipos 2
def convert_dataframe_types(dataframe):
    # Itera sobre cada nombre de columna en el DataFrame
    for column_name in dataframe.columns:
        # Convierte el tipo de la columna llamando a la función convert_column_type
        dataframe[column_name] = convert_column_type(dataframe[column_name])

    return dataframe  # Devuelve el DataFrame con las columnas convertidas

# %%
# column_types 
column_types = loans.dtypes
column_types
# Out:
# Unnamed: 0                 int64
# id                         int64
# member_id                float64
# loan_amnt                float64
# funded_amnt              float64
#                           ...
# settlement_status         object
# settlement_date           object
# settlement_amount        float64
# settlement_percentage    float64
# settlement_term          float64
# Length: 151, dtype: object

# %% [markdown]
# ## Manejo de NaNs o missings

# %% [markdown]
# Maneja los datos de tipos missing. Elije una estrategia adecuada dependiendo del tipo de dato que le asignaste a la columna.

# %% [markdown]
# Crea codigo para **guardar** y **cargar** un archivo JSON en el que se guarde la `estrategia` y `valor` que utilizaste para **imputar**. Por ejemplo: Si hay una columna que se llama `columna 3` y utilizaste la estrategia de imputacion de media, y existe otra llamada `columna 4` y  elegiste la palabra 'missing' el JSON debera contener:
#
#  `{'columna 3':{'estrategia':'mean', 'valor':3.4}, 'columna 4':{'estrategia':'identificador', 'valor':'missing'}}`
#
#  De tal manera que para cada columna que tenga un metodo de imputacion apunte a otro diccionario donde el **key** `estrategia` describa de manera sencilla el metodo, y el **key** `valor` el valor usado. En general:
#  `{'nombre de la columna':{'estrategia':'descripcion de estrategia', 'valor':'valor utilizado'}}`.
#
#
# De utilizar mas de un metodo puedes anidarlos en una lista
#   `[{...},{...}]`.
#
# Incluso si la columna utilizada no sufrio imputacion, es necesario que la agregues al JSON.
#
# La idea es que cualquier otra persona pueda cargar el el archivo JSON con tu funcion, entender que hiciste y replicarlo facilmente. No existe solo una respuesta correcta, pero tendras que justificar y explicar tus deciciones.

# %% [markdown]
# ### Imputacion

# %%
# Tu codigo aqui
imput_dict = {}
loans.replace('', np.nan, inplace=True) # reemplazamos los espacios en blanco por nans
def imputacion (dataframe):
    for column_name in dataframe.columns:
        if dataframe[column_name].dtype == 'int64':
            dataframe[column_name].fillna(int(dataframe[column_name].mean()), inplace=True)
            imput_dict[column_name] = {'estrategia': 'llenar con la media', 'valor': int(dataframe[column_name].mean())}
        # si la columna es int, la llenamos con la media para intentar no cambiar el como se distribuyen los datos
        if dataframe[column_name].dtype == 'float64':
            dataframe[column_name].fillna(dataframe[column_name].mean(), inplace=True)
            imput_dict[column_name] = {'estrategia': 'llenar con la media', 'valor': dataframe[column_name].mean()}
        # si la columna es float, la llenamos con la media para intentar no cambiar el como se distribuyen los datos
        if dataframe[column_name].dtype == 'object':
            dataframe[column_name].fillna(dataframe[column_name].mode(), inplace=True)
            imput_dict[column_name] = {'estrategia': 'llenar con la moda', 'valor': str(dataframe[column_name].mode())}
        # si la columna es de objetos, la llenamos con la moda para intentar seguir la tendencia de distribución de los datos
        if dataframe[column_name].dtype == 'string':
            dataframe[column_name].fillna(dataframe[column_name].mode(), inplace=True)
            imput_dict[column_name] = {'estrategia': 'llenar con la moda', 'valor': str(dataframe[column_name].mode())}
        # si la columna es de cadenas, la llenamos con la moda para intentar seguir la tendencia de distribución de los datos
        if dataframe[column_name].isnull().mean()>= .1:
            dataframe.drop(column_name, axis=1, inplace=True)
        # dropeamos las columnas que sean la mitad o más nans, para reducir las columnas vacias    
    return dataframe 
loans
# Out:
#        Unnamed: 0        id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0               0  38098114    15000.0      15000.0          15000.0
# 1               1  36805548    10400.0      10400.0          10400.0
# 2               2  37842129    21425.0      21425.0          21425.0
# 3               3  37612354    12800.0      12800.0          12800.0
# 4               4  37662224     7650.0       7650.0           7650.0
# ...           ...       ...        ...          ...              ...
# 99995       99995  22454240     8400.0       8400.0           8400.0
# 99996       99996  11396920    10000.0      10000.0          10000.0
# 99997       99997   8556176    30000.0      30000.0          30000.0
# 99998       99998  24023408     8475.0       8475.0           8475.0
# 99999       99999  24023398    25000.0      25000.0          25000.0
#
#              term  int_rate  installment grade sub_grade  ...  \
# 0       60 months     12.39       336.64     C        C1  ...
# 1       36 months      6.99       321.08     A        A3  ...
# 2       60 months     15.59       516.36     D        D1  ...
# 3       60 months     17.14       319.08     D        D4  ...
# 4       36 months     13.66       260.20     C        C3  ...
# ...           ...       ...          ...   ...       ...  ...
# 99995   36 months      9.17       267.79     B        B1  ...
# 99996   36 months     12.99       336.90     C        C1  ...
# 99997   60 months     20.99       811.44     E        E4  ...
# 99998   36 months     24.99       336.92     F        F4  ...
# 99999   36 months     10.15       808.45     B        B2  ...
#
#       hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                        8046.616541                   186.563135
# 1                        8046.616541                   186.563135
# 2                        8046.616541                   186.563135
# 3                        8046.616541                   186.563135
# 4                        8046.616541                   186.563135
# ...                              ...                          ...
# 99995                    8046.616541                   186.563135
# 99996                    8046.616541                   186.563135
# 99997                    8046.616541                   186.563135
# 99998                    8046.616541                   186.563135
# 99999                    8046.616541                   186.563135
#
#       disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                    Cash                     N                  Sep-2017
# 1                    Cash                     N                  Sep-2017
# 2                    Cash                     N                  Sep-2017
# 3                    Cash                     N                  Sep-2017
# 4                    Cash                     N                  Sep-2017
# ...                   ...                   ...                       ...
# 99995                Cash                     N                  Sep-2017
# 99996                Cash                     N                  Sep-2017
# 99997                Cash                     N                  Sep-2017
# 99998                Cash                     N                  Sep-2017
# 99999                Cash                     N                  Sep-2017
#
#       settlement_status settlement_date settlement_amount  \
# 0                ACTIVE        Apr-2017       4768.376357
# 1                ACTIVE        Apr-2017       4768.376357
# 2                ACTIVE        Apr-2017       4768.376357
# 3                ACTIVE        Apr-2017       4768.376357
# 4                ACTIVE        Apr-2017       4768.376357
# ...                 ...             ...               ...
# 99995            ACTIVE        Apr-2017       4768.376357
# 99996            ACTIVE        Apr-2017       4768.376357
# 99997            ACTIVE        Apr-2017       4768.376357
# 99998            ACTIVE        Apr-2017       4768.376357
# 99999            ACTIVE        Apr-2017       4768.376357
#
#       settlement_percentage settlement_term
# 0                 47.720519        8.265116
# 1                 47.720519        8.265116
# 2                 47.720519        8.265116
# 3                 47.720519        8.265116
# 4                 47.720519        8.265116
# ...                     ...             ...
# 99995             47.720519        8.265116
# 99996             47.720519        8.265116
# 99997             47.720519        8.265116
# 99998             47.720519        8.265116
# 99999             47.720519        8.265116
#
# [100000 rows x 120 columns]

# %%
# TU codigo aqui
loans = imputacion(loans)

imput_dict
# Out:
# /var/folders/7r/6s1q_b2x7rldv60cty2jvx440000gn/T/ipykernel_4389/3600428040.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataframe[column_name].fillna(int(dataframe[column_name].mean()), inplace=True)
# /var/folders/7r/6s1q_b2x7rldv60cty2jvx440000gn/T/ipykernel_4389/3600428040.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataframe[column_name].fillna(dataframe[column_name].mean(), inplace=True)
# /var/folders/7r/6s1q_b2x7rldv60cty2jvx440000gn/T/ipykernel_4389/3600428040.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataframe[column_name].fillna(dataframe[column_name].mode(), inplace=True)
# {'Unnamed: 0': {'estrategia': 'llenar con la media', 'valor': 49999},
#  'id': {'estrategia': 'llenar con la media', 'valor': 30299954},
#  'loan_amnt': {'estrategia': 'llenar con la media', 'valor': 14886.93},
#  'funded_amnt': {'estrategia': 'llenar con la media', 'valor': 14886.93},
#  'funded_amnt_inv': {'estrategia': 'llenar con la media', 'valor': 14883.9105},
#  'term': {'estrategia': 'llenar con la moda',
#   'valor': '0     36 months\nName: term, dtype: object'},
#  'int_rate': {'estrategia': 'llenar con la media', 'valor': 13.2780734},
#  'installment': {'estrategia': 'llenar con la media',
#   'valor': 437.3318244000001},
#  'grade': {'estrategia': 'llenar con la moda',
#   'valor': '0    C\nName: grade, dtype: object'},
#  'sub_grade': {'estrategia': 'llenar con la moda',
#   'valor': '0    C1\nName: sub_grade, dtype: object'},
#  'emp_title': {'estrategia': 'llenar con la moda',
#   'valor': '0    Teacher\nName: emp_title, dtype: object'},
#  'emp_length': {'estrategia': 'llenar con la moda',
#   'valor': '0    10+ years\nName: emp_length, dtype: object'},
#  'home_ownership': {'estrategia': 'llenar con la moda',
#   'valor': '0    MORTGAGE\nName: home_ownership, dtype: object'},
#  'annual_inc': {'estrategia': 'llenar con la media', 'valor': 74689.2425825},
#  'verification_status': {'estrategia': 'llenar con la moda',
#   'valor': '0    Source Verified\nName: verification_status, dtype: object'},
#  'issue_d': {'estrategia': 'llenar con la moda',
#   'valor': '0    Oct-2014\nName: issue_d, dtype: object'},
#  'loan_status': {'estrategia': 'llenar con la moda',
#   'valor': '0    Fully Paid\nName: loan_status, dtype: object'},
#  'pymnt_plan': {'estrategia': 'llenar con la moda',
#   'valor': '0    n\nName: pymnt_plan, dtype: object'},
#  'desc': {'estrategia': 'llenar con la moda',
#   'valor': '0     \nName: desc, dtype: object'},
#  'purpose': {'estrategia': 'llenar con la moda',
#   'valor': '0    debt_consolidation\nName: purpose, dtype: object'},
#  'title': {'estrategia': 'llenar con la moda',
#   'valor': '0    Debt consolidation\nName: title, dtype: object'},
#  'zip_code': {'estrategia': 'llenar con la moda',
#   'valor': '0    750xx\nName: zip_code, dtype: object'},
#  'addr_state': {'estrategia': 'llenar con la moda',
#   'valor': '0    CA\nName: addr_state, dtype: object'},
#  'dti': {'estrategia': 'llenar con la media', 'valor': 18.7697866},
#  'delinq_2yrs': {'estrategia': 'llenar con la media', 'valor': 0.34392},
#  'earliest_cr_line': {'estrategia': 'llenar con la moda',
#   'valor': '0    Aug-2001\nName: earliest_cr_line, dtype: object'},
#  'fico_range_low': {'estrategia': 'llenar con la media', 'valor': 692.5798},
#  'fico_range_high': {'estrategia': 'llenar con la media', 'valor': 696.57987},
#  'inq_last_6mths': {'estrategia': 'llenar con la media', 'valor': 0.62189},
#  'mths_since_last_delinq': {'estrategia': 'llenar con la media',
#   'valor': 33.52252568376319},
#  'mths_since_last_record': {'estrategia': 'llenar con la media',
#   'valor': 69.39421467846044},
#  'open_acc': {'estrategia': 'llenar con la media', 'valor': 11.83275},
#  'pub_rec': {'estrategia': 'llenar con la media', 'valor': 0.21456},
#  'revol_bal': {'estrategia': 'llenar con la media', 'valor': 17588.06238},
#  'revol_util': {'estrategia': 'llenar con la media',
#   'valor': 55.43498459137117},
#  'total_acc': {'estrategia': 'llenar con la media', 'valor': 26.03486},
#  'initial_list_status': {'estrategia': 'llenar con la moda',
#   'valor': '0    w\nName: initial_list_status, dtype: object'},
#  'out_prncp': {'estrategia': 'llenar con la media',
#   'valor': 1215.1084604999999},
#  'out_prncp_inv': {'estrategia': 'llenar con la media', 'valor': 1214.9064667},
#  'total_pymnt': {'estrategia': 'llenar con la media',
#   'valor': 15210.210257400642},
#  'total_pymnt_inv': {'estrategia': 'llenar con la media',
#   'valor': 15207.1216847},
#  'total_rec_prncp': {'estrategia': 'llenar con la media',
#   'valor': 11978.8756247},
#  'total_rec_int': {'estrategia': 'llenar con la media',
#   'valor': 3040.9570177000005},
#  'total_rec_late_fee': {'estrategia': 'llenar con la media',
#   'valor': 1.2300369003639051},
#  'recoveries': {'estrategia': 'llenar con la media',
#   'valor': 189.14756099939245},
#  'collection_recovery_fee': {'estrategia': 'llenar con la media',
#   'valor': 31.41689079499522},
#  'last_pymnt_d': {'estrategia': 'llenar con la moda',
#   'valor': '0    Dec-2017\nName: last_pymnt_d, dtype: object'},
#  'last_pymnt_amnt': {'estrategia': 'llenar con la media',
#   'valor': 4165.111319039872},
#  'next_pymnt_d': {'estrategia': 'llenar con la moda',
#   'valor': '0    Jan-2018\nName: next_pymnt_d, dtype: object'},
#  'last_credit_pull_d': {'estrategia': 'llenar con la moda',
#   'valor': '0    Dec-2017\nName: last_credit_pull_d, dtype: object'},
#  'last_fico_range_high': {'estrategia': 'llenar con la media',
#   'valor': 677.92764},
#  'last_fico_range_low': {'estrategia': 'llenar con la media',
#   'valor': 664.18765},
#  'collections_12_mths_ex_med': {'estrategia': 'llenar con la media',
#   'valor': 0.01701},
#  'mths_since_last_major_derog': {'estrategia': 'llenar con la media',
#   'valor': 43.45123653412547},
#  'policy_code': {'estrategia': 'llenar con la media', 'valor': 1.0},
#  'application_type': {'estrategia': 'llenar con la moda',
#   'valor': '0    Individual\nName: application_type, dtype: object'},
#  'acc_now_delinq': {'estrategia': 'llenar con la media', 'valor': 0.00638},
#  'tot_coll_amt': {'estrategia': 'llenar con la media', 'valor': 235.46884},
#  'tot_cur_bal': {'estrategia': 'llenar con la media', 'valor': 140910.91011},
#  'total_rev_hi_lim': {'estrategia': 'llenar con la media',
#   'valor': 32526.9722},
#  'acc_open_past_24mths': {'estrategia': 'llenar con la media',
#   'valor': 4.52473},
#  'avg_cur_bal': {'estrategia': 'llenar con la media', 'valor': 13337.70501},
#  'bc_open_to_buy': {'estrategia': 'llenar con la media',
#   'valor': 8956.451808021038},
#  'bc_util': {'estrategia': 'llenar con la media', 'valor': 64.5600220643307},
#  'chargeoff_within_12_mths': {'estrategia': 'llenar con la media',
#   'valor': 0.0104},
#  'delinq_amnt': {'estrategia': 'llenar con la media', 'valor': 11.5565},
#  'mo_sin_old_il_acct': {'estrategia': 'llenar con la media',
#   'valor': 127.73700163929357},
#  'mo_sin_old_rev_tl_op': {'estrategia': 'llenar con la media',
#   'valor': 185.82682},
#  'mo_sin_rcnt_rev_tl_op': {'estrategia': 'llenar con la media',
#   'valor': 13.13111},
#  'mo_sin_rcnt_tl': {'estrategia': 'llenar con la media', 'valor': 7.94572},
#  'mort_acc': {'estrategia': 'llenar con la media', 'valor': 1.78588},
#  'mths_since_recent_bc': {'estrategia': 'llenar con la media',
#   'valor': 24.435205303635133},
#  'mths_since_recent_bc_dlq': {'estrategia': 'llenar con la media',
#   'valor': 39.633868833868846},
#  'mths_since_recent_inq': {'estrategia': 'llenar con la media',
#   'valor': 6.7667716395733075},
#  'mths_since_recent_revol_delinq': {'estrategia': 'llenar con la media',
#   'valor': 35.61543138230253},
#  'num_accts_ever_120_pd': {'estrategia': 'llenar con la media',
#   'valor': 0.52372},
#  'num_actv_bc_tl': {'estrategia': 'llenar con la media', 'valor': 3.72897},
#  'num_actv_rev_tl': {'estrategia': 'llenar con la media', 'valor': 5.83361},
#  'num_bc_sats': {'estrategia': 'llenar con la media', 'valor': 4.66532},
#  'num_bc_tl': {'estrategia': 'llenar con la media', 'valor': 8.42365},
#  'num_il_tl': {'estrategia': 'llenar con la media', 'valor': 8.66296},
#  'num_op_rev_tl': {'estrategia': 'llenar con la media', 'valor': 8.39263},
#  'num_rev_accts': {'estrategia': 'llenar con la media', 'valor': 15.28991},
#  'num_rev_tl_bal_gt_0': {'estrategia': 'llenar con la media',
#   'valor': 5.81747},
#  'num_sats': {'estrategia': 'llenar con la media', 'valor': 11.79017},
#  'num_tl_120dpd_2m': {'estrategia': 'llenar con la media',
#   'valor': 0.0008159601811431601},
#  'num_tl_30dpd': {'estrategia': 'llenar con la media', 'valor': 0.00444},
#  'num_tl_90g_dpd_24m': {'estrategia': 'llenar con la media', 'valor': 0.09143},
#  'num_tl_op_past_12m': {'estrategia': 'llenar con la media', 'valor': 2.0957},
#  'pct_tl_nvr_dlq': {'estrategia': 'llenar con la media', 'valor': 94.300697},
#  'percent_bc_gt_75': {'estrategia': 'llenar con la media',
#   'valor': 50.69469642550006},
#  'pub_rec_bankruptcies': {'estrategia': 'llenar con la media',
#   'valor': 0.12654},
#  'tax_liens': {'estrategia': 'llenar con la media', 'valor': 0.05618},
#  'tot_hi_cred_lim': {'estrategia': 'llenar con la media',
#   'valor': 172385.51452},
#  'total_bal_ex_mort': {'estrategia': 'llenar con la media',
#   'valor': 50471.32121},
#  'total_bc_limit': {'estrategia': 'llenar con la media', 'valor': 21073.77013},
#  'total_il_high_credit_limit': {'estrategia': 'llenar con la media',
#   'valor': 41031.31849},
#  'hardship_flag': {'estrategia': 'llenar con la moda',
#   'valor': '0    N\nName: hardship_flag, dtype: object'},
#  'hardship_type': {'estrategia': 'llenar con la moda',
#   'valor': '0    INTEREST ONLY-3 MONTHS DEFERRAL\nName: hardship_type, dtype: object'},
#  'hardship_reason': {'estrategia': 'llenar con la moda',
#   'valor': '0    NATURAL_DISASTER\nName: hardship_reason, dtype: object'},
#  'hardship_status': {'estrategia': 'llenar con la moda',
#   'valor': '0    COMPLETED\nName: hardship_status, dtype: object'},
#  'deferral_term': {'estrategia': 'llenar con la media', 'valor': 3.0},
#  'hardship_amount': {'estrategia': 'llenar con la media',
#   'valor': 110.33556756756752},
#  'hardship_start_date': {'estrategia': 'llenar con la moda',
#   'valor': '0    Sep-2017\nName: hardship_start_date, dtype: object'},
#  'hardship_end_date': {'estrategia': 'llenar con la moda',
#   'valor': '0    Dec-2017\nName: hardship_end_date, dtype: object'},
#  'payment_plan_start_date': {'estrategia': 'llenar con la moda',
#   'valor': '0    Sep-2017\nName: payment_plan_start_date, dtype: object'},
#  'hardship_length': {'estrategia': 'llenar con la media', 'valor': 3.0},
#  'hardship_dpd': {'estrategia': 'llenar con la media',
#   'valor': 14.037837837837836},
#  'hardship_loan_status': {'estrategia': 'llenar con la moda',
#   'valor': '0    Late (16-30 days)\nName: hardship_loan_status, dtype: object'},
#  'orig_projected_additional_accrued_interest': {'estrategia': 'llenar con la media',
#   'valor': 323.49513157894734},
#  'hardship_payoff_balance_amount': {'estrategia': 'llenar con la media',
#   'valor': 8046.616540540536},
#  'hardship_last_payment_amount': {'estrategia': 'llenar con la media',
#   'valor': 186.56313513513516},
#  'disbursement_method': {'estrategia': 'llenar con la moda',
#   'valor': '0    Cash\nName: disbursement_method, dtype: object'},
#  'debt_settlement_flag': {'estrategia': 'llenar con la moda',
#   'valor': '0    N\nName: debt_settlement_flag, dtype: object'},
#  'debt_settlement_flag_date': {'estrategia': 'llenar con la moda',
#   'valor': '0    Sep-2017\nName: debt_settlement_flag_date, dtype: object'},
#  'settlement_status': {'estrategia': 'llenar con la moda',
#   'valor': '0    ACTIVE\nName: settlement_status, dtype: object'},
#  'settlement_date': {'estrategia': 'llenar con la moda',
#   'valor': '0    Apr-2017\nName: settlement_date, dtype: object'},
#  'settlement_amount': {'estrategia': 'llenar con la media',
#   'valor': 4768.376356589147},
#  'settlement_percentage': {'estrategia': 'llenar con la media',
#   'valor': 47.72051937984495},
#  'settlement_term': {'estrategia': 'llenar con la media',
#   'valor': 8.265116279069767}}

# %% [markdown]
# ### Codigo para salvar y cargar JSONs

# %%
with open('imput_dict.json', 'w') as f:
    json.dump(imput_dict, f)

# %%
with open('imput_dict.json', 'r') as o:
    json_dict = json.load(o)
json_dict
# Out:
# {'Unnamed: 0': {'estrategia': 'llenar con la media', 'valor': 49999},
#  'id': {'estrategia': 'llenar con la media', 'valor': 30299954},
#  'loan_amnt': {'estrategia': 'llenar con la media', 'valor': 14886.93},
#  'funded_amnt': {'estrategia': 'llenar con la media', 'valor': 14886.93},
#  'funded_amnt_inv': {'estrategia': 'llenar con la media', 'valor': 14883.9105},
#  'term': {'estrategia': 'llenar con la moda',
#   'valor': '0     36 months\nName: term, dtype: object'},
#  'int_rate': {'estrategia': 'llenar con la media', 'valor': 13.2780734},
#  'installment': {'estrategia': 'llenar con la media',
#   'valor': 437.3318244000001},
#  'grade': {'estrategia': 'llenar con la moda',
#   'valor': '0    C\nName: grade, dtype: object'},
#  'sub_grade': {'estrategia': 'llenar con la moda',
#   'valor': '0    C1\nName: sub_grade, dtype: object'},
#  'emp_title': {'estrategia': 'llenar con la moda',
#   'valor': '0    Teacher\nName: emp_title, dtype: object'},
#  'emp_length': {'estrategia': 'llenar con la moda',
#   'valor': '0    10+ years\nName: emp_length, dtype: object'},
#  'home_ownership': {'estrategia': 'llenar con la moda',
#   'valor': '0    MORTGAGE\nName: home_ownership, dtype: object'},
#  'annual_inc': {'estrategia': 'llenar con la media', 'valor': 74689.2425825},
#  'verification_status': {'estrategia': 'llenar con la moda',
#   'valor': '0    Source Verified\nName: verification_status, dtype: object'},
#  'issue_d': {'estrategia': 'llenar con la moda',
#   'valor': '0    Oct-2014\nName: issue_d, dtype: object'},
#  'loan_status': {'estrategia': 'llenar con la moda',
#   'valor': '0    Fully Paid\nName: loan_status, dtype: object'},
#  'pymnt_plan': {'estrategia': 'llenar con la moda',
#   'valor': '0    n\nName: pymnt_plan, dtype: object'},
#  'desc': {'estrategia': 'llenar con la moda',
#   'valor': '0     \nName: desc, dtype: object'},
#  'purpose': {'estrategia': 'llenar con la moda',
#   'valor': '0    debt_consolidation\nName: purpose, dtype: object'},
#  'title': {'estrategia': 'llenar con la moda',
#   'valor': '0    Debt consolidation\nName: title, dtype: object'},
#  'zip_code': {'estrategia': 'llenar con la moda',
#   'valor': '0    750xx\nName: zip_code, dtype: object'},
#  'addr_state': {'estrategia': 'llenar con la moda',
#   'valor': '0    CA\nName: addr_state, dtype: object'},
#  'dti': {'estrategia': 'llenar con la media', 'valor': 18.7697866},
#  'delinq_2yrs': {'estrategia': 'llenar con la media', 'valor': 0.34392},
#  'earliest_cr_line': {'estrategia': 'llenar con la moda',
#   'valor': '0    Aug-2001\nName: earliest_cr_line, dtype: object'},
#  'fico_range_low': {'estrategia': 'llenar con la media', 'valor': 692.5798},
#  'fico_range_high': {'estrategia': 'llenar con la media', 'valor': 696.57987},
#  'inq_last_6mths': {'estrategia': 'llenar con la media', 'valor': 0.62189},
#  'mths_since_last_delinq': {'estrategia': 'llenar con la media',
#   'valor': 33.52252568376319},
#  'mths_since_last_record': {'estrategia': 'llenar con la media',
#   'valor': 69.39421467846044},
#  'open_acc': {'estrategia': 'llenar con la media', 'valor': 11.83275},
#  'pub_rec': {'estrategia': 'llenar con la media', 'valor': 0.21456},
#  'revol_bal': {'estrategia': 'llenar con la media', 'valor': 17588.06238},
#  'revol_util': {'estrategia': 'llenar con la media',
#   'valor': 55.43498459137117},
#  'total_acc': {'estrategia': 'llenar con la media', 'valor': 26.03486},
#  'initial_list_status': {'estrategia': 'llenar con la moda',
#   'valor': '0    w\nName: initial_list_status, dtype: object'},
#  'out_prncp': {'estrategia': 'llenar con la media',
#   'valor': 1215.1084604999999},
#  'out_prncp_inv': {'estrategia': 'llenar con la media', 'valor': 1214.9064667},
#  'total_pymnt': {'estrategia': 'llenar con la media',
#   'valor': 15210.210257400642},
#  'total_pymnt_inv': {'estrategia': 'llenar con la media',
#   'valor': 15207.1216847},
#  'total_rec_prncp': {'estrategia': 'llenar con la media',
#   'valor': 11978.8756247},
#  'total_rec_int': {'estrategia': 'llenar con la media',
#   'valor': 3040.9570177000005},
#  'total_rec_late_fee': {'estrategia': 'llenar con la media',
#   'valor': 1.2300369003639051},
#  'recoveries': {'estrategia': 'llenar con la media',
#   'valor': 189.14756099939245},
#  'collection_recovery_fee': {'estrategia': 'llenar con la media',
#   'valor': 31.41689079499522},
#  'last_pymnt_d': {'estrategia': 'llenar con la moda',
#   'valor': '0    Dec-2017\nName: last_pymnt_d, dtype: object'},
#  'last_pymnt_amnt': {'estrategia': 'llenar con la media',
#   'valor': 4165.111319039872},
#  'next_pymnt_d': {'estrategia': 'llenar con la moda',
#   'valor': '0    Jan-2018\nName: next_pymnt_d, dtype: object'},
#  'last_credit_pull_d': {'estrategia': 'llenar con la moda',
#   'valor': '0    Dec-2017\nName: last_credit_pull_d, dtype: object'},
#  'last_fico_range_high': {'estrategia': 'llenar con la media',
#   'valor': 677.92764},
#  'last_fico_range_low': {'estrategia': 'llenar con la media',
#   'valor': 664.18765},
#  'collections_12_mths_ex_med': {'estrategia': 'llenar con la media',
#   'valor': 0.01701},
#  'mths_since_last_major_derog': {'estrategia': 'llenar con la media',
#   'valor': 43.45123653412547},
#  'policy_code': {'estrategia': 'llenar con la media', 'valor': 1.0},
#  'application_type': {'estrategia': 'llenar con la moda',
#   'valor': '0    Individual\nName: application_type, dtype: object'},
#  'acc_now_delinq': {'estrategia': 'llenar con la media', 'valor': 0.00638},
#  'tot_coll_amt': {'estrategia': 'llenar con la media', 'valor': 235.46884},
#  'tot_cur_bal': {'estrategia': 'llenar con la media', 'valor': 140910.91011},
#  'total_rev_hi_lim': {'estrategia': 'llenar con la media',
#   'valor': 32526.9722},
#  'acc_open_past_24mths': {'estrategia': 'llenar con la media',
#   'valor': 4.52473},
#  'avg_cur_bal': {'estrategia': 'llenar con la media', 'valor': 13337.70501},
#  'bc_open_to_buy': {'estrategia': 'llenar con la media',
#   'valor': 8956.451808021038},
#  'bc_util': {'estrategia': 'llenar con la media', 'valor': 64.5600220643307},
#  'chargeoff_within_12_mths': {'estrategia': 'llenar con la media',
#   'valor': 0.0104},
#  'delinq_amnt': {'estrategia': 'llenar con la media', 'valor': 11.5565},
#  'mo_sin_old_il_acct': {'estrategia': 'llenar con la media',
#   'valor': 127.73700163929357},
#  'mo_sin_old_rev_tl_op': {'estrategia': 'llenar con la media',
#   'valor': 185.82682},
#  'mo_sin_rcnt_rev_tl_op': {'estrategia': 'llenar con la media',
#   'valor': 13.13111},
#  'mo_sin_rcnt_tl': {'estrategia': 'llenar con la media', 'valor': 7.94572},
#  'mort_acc': {'estrategia': 'llenar con la media', 'valor': 1.78588},
#  'mths_since_recent_bc': {'estrategia': 'llenar con la media',
#   'valor': 24.435205303635133},
#  'mths_since_recent_bc_dlq': {'estrategia': 'llenar con la media',
#   'valor': 39.633868833868846},
#  'mths_since_recent_inq': {'estrategia': 'llenar con la media',
#   'valor': 6.7667716395733075},
#  'mths_since_recent_revol_delinq': {'estrategia': 'llenar con la media',
#   'valor': 35.61543138230253},
#  'num_accts_ever_120_pd': {'estrategia': 'llenar con la media',
#   'valor': 0.52372},
#  'num_actv_bc_tl': {'estrategia': 'llenar con la media', 'valor': 3.72897},
#  'num_actv_rev_tl': {'estrategia': 'llenar con la media', 'valor': 5.83361},
#  'num_bc_sats': {'estrategia': 'llenar con la media', 'valor': 4.66532},
#  'num_bc_tl': {'estrategia': 'llenar con la media', 'valor': 8.42365},
#  'num_il_tl': {'estrategia': 'llenar con la media', 'valor': 8.66296},
#  'num_op_rev_tl': {'estrategia': 'llenar con la media', 'valor': 8.39263},
#  'num_rev_accts': {'estrategia': 'llenar con la media', 'valor': 15.28991},
#  'num_rev_tl_bal_gt_0': {'estrategia': 'llenar con la media',
#   'valor': 5.81747},
#  'num_sats': {'estrategia': 'llenar con la media', 'valor': 11.79017},
#  'num_tl_120dpd_2m': {'estrategia': 'llenar con la media',
#   'valor': 0.0008159601811431601},
#  'num_tl_30dpd': {'estrategia': 'llenar con la media', 'valor': 0.00444},
#  'num_tl_90g_dpd_24m': {'estrategia': 'llenar con la media', 'valor': 0.09143},
#  'num_tl_op_past_12m': {'estrategia': 'llenar con la media', 'valor': 2.0957},
#  'pct_tl_nvr_dlq': {'estrategia': 'llenar con la media', 'valor': 94.300697},
#  'percent_bc_gt_75': {'estrategia': 'llenar con la media',
#   'valor': 50.69469642550006},
#  'pub_rec_bankruptcies': {'estrategia': 'llenar con la media',
#   'valor': 0.12654},
#  'tax_liens': {'estrategia': 'llenar con la media', 'valor': 0.05618},
#  'tot_hi_cred_lim': {'estrategia': 'llenar con la media',
#   'valor': 172385.51452},
#  'total_bal_ex_mort': {'estrategia': 'llenar con la media',
#   'valor': 50471.32121},
#  'total_bc_limit': {'estrategia': 'llenar con la media', 'valor': 21073.77013},
#  'total_il_high_credit_limit': {'estrategia': 'llenar con la media',
#   'valor': 41031.31849},
#  'hardship_flag': {'estrategia': 'llenar con la moda',
#   'valor': '0    N\nName: hardship_flag, dtype: object'},
#  'hardship_type': {'estrategia': 'llenar con la moda',
#   'valor': '0    INTEREST ONLY-3 MONTHS DEFERRAL\nName: hardship_type, dtype: object'},
#  'hardship_reason': {'estrategia': 'llenar con la moda',
#   'valor': '0    NATURAL_DISASTER\nName: hardship_reason, dtype: object'},
#  'hardship_status': {'estrategia': 'llenar con la moda',
#   'valor': '0    COMPLETED\nName: hardship_status, dtype: object'},
#  'deferral_term': {'estrategia': 'llenar con la media', 'valor': 3.0},
#  'hardship_amount': {'estrategia': 'llenar con la media',
#   'valor': 110.33556756756752},
#  'hardship_start_date': {'estrategia': 'llenar con la moda',
#   'valor': '0    Sep-2017\nName: hardship_start_date, dtype: object'},
#  'hardship_end_date': {'estrategia': 'llenar con la moda',
#   'valor': '0    Dec-2017\nName: hardship_end_date, dtype: object'},
#  'payment_plan_start_date': {'estrategia': 'llenar con la moda',
#   'valor': '0    Sep-2017\nName: payment_plan_start_date, dtype: object'},
#  'hardship_length': {'estrategia': 'llenar con la media', 'valor': 3.0},
#  'hardship_dpd': {'estrategia': 'llenar con la media',
#   'valor': 14.037837837837836},
#  'hardship_loan_status': {'estrategia': 'llenar con la moda',
#   'valor': '0    Late (16-30 days)\nName: hardship_loan_status, dtype: object'},
#  'orig_projected_additional_accrued_interest': {'estrategia': 'llenar con la media',
#   'valor': 323.49513157894734},
#  'hardship_payoff_balance_amount': {'estrategia': 'llenar con la media',
#   'valor': 8046.616540540536},
#  'hardship_last_payment_amount': {'estrategia': 'llenar con la media',
#   'valor': 186.56313513513516},
#  'disbursement_method': {'estrategia': 'llenar con la moda',
#   'valor': '0    Cash\nName: disbursement_method, dtype: object'},
#  'debt_settlement_flag': {'estrategia': 'llenar con la moda',
#   'valor': '0    N\nName: debt_settlement_flag, dtype: object'},
#  'debt_settlement_flag_date': {'estrategia': 'llenar con la moda',
#   'valor': '0    Sep-2017\nName: debt_settlement_flag_date, dtype: object'},
#  'settlement_status': {'estrategia': 'llenar con la moda',
#   'valor': '0    ACTIVE\nName: settlement_status, dtype: object'},
#  'settlement_date': {'estrategia': 'llenar con la moda',
#   'valor': '0    Apr-2017\nName: settlement_date, dtype: object'},
#  'settlement_amount': {'estrategia': 'llenar con la media',
#   'valor': 4768.376356589147},
#  'settlement_percentage': {'estrategia': 'llenar con la media',
#   'valor': 47.72051937984495},
#  'settlement_term': {'estrategia': 'llenar con la media',
#   'valor': 8.265116279069767}}
