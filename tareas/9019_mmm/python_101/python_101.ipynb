# %%
import time
import numpy as np
from joblib import Parallel, delayed

# Ejemplo de bucle for pesado para suma de matrices
def suma_matrices(a, b):
    filas, columnas = len(a), len(a[0])
    resultado = [[0 for _ in range(columnas)] for _ in range(filas)]
    
    for i in range(filas):
        for j in range(columnas):
            resultado[i][j] = a[i][j] + b[i][j]
    
    return resultado

# Ejemplo de vectorización con NumPy para suma de matrices
def suma_matrices_vectorizada(a, b):
    a_np = np.array(a)
    b_np = np.array(b)
    resultado_np = a_np + b_np
    return resultado_np.tolist()

# Paralelizar la suma de matrices utilizando joblib
def suma_matrices_paralela(a, b):
    filas, columnas = len(a), len(a[0])
    
    def suma_elemento(i, j):
        return a[i][j] + b[i][j]
    
    resultado = Parallel(n_jobs=-1)(delayed(suma_elemento)(i, j) for i in range(filas) for j in range(columnas))
    
    # Reshape para obtener la matriz resultante
    resultado = np.array(resultado).reshape(filas, columnas)
    
    return resultado.tolist()

# Crear matrices de ejemplo
matriz_a = np.random.randint(1, 10, size=(1000, 1000))
matriz_b = np.random.randint(1, 10, size=(1000, 1000))

# Medir tiempo de ejecución para la implementación paralela
inicio_paralelo = time.time()
resultado_paralelo = suma_matrices_paralela(matriz_a, matriz_b)
fin_paralelo = time.time()
tiempo_paralelo = fin_paralelo - inicio_paralelo

# Medir tiempo de ejecución para la implementación con bucles
inicio_bucle = time.time()
resultado_bucle = suma_matrices(matriz_a, matriz_b)
fin_bucle = time.time()
tiempo_bucle = fin_bucle - inicio_bucle

# Medir tiempo de ejecución para la implementación vectorizada
inicio_vectorizado = time.time()
resultado_vectorizado = suma_matrices_vectorizada(matriz_a, matriz_b)
fin_vectorizado = time.time()
tiempo_vectorizado = fin_vectorizado - inicio_vectorizado

# Imprimir resultados
print("Resultado con bucles:", resultado_bucle)
print("Tiempo con bucles:", tiempo_bucle, "segundos")

print("\nResultado vectorizado:", resultado_vectorizado)
print("Tiempo vectorizado:", tiempo_vectorizado, "segundos")

print("\nResultado paralelo:", resultado_paralelo)
print("Tiempo paralelo:", tiempo_paralelo, "segundos")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 43
#      41 # Medir tiempo de ejecución para la implementación paralela
#      42 inicio_paralelo = time.time()
# ---> 43 resultado_paralelo = suma_matrices_paralela(matriz_a, matriz_b)
#      44 fin_paralelo = time.time()
#      45 tiempo_paralelo = fin_paralelo - inicio_paralelo
#
# Cell In[6], line 30, in suma_matrices_paralela(a, b)
#      27 def suma_elemento(i, j):
#      28     return a[i][j] + b[i][j]
# ---> 30 resultado = Parallel(n_jobs=-1)(delayed(suma_elemento)(i, j) for i in range(filas) for j in range(columnas))
#      32 # Reshape para obtener la matriz resultante
#      33 resultado = np.array(resultado).reshape(filas, columnas)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:556, in LokyBackend.apply_async(self, func, callback)
#     554 def apply_async(self, func, callback=None):
#     555     """Schedule a func to be run"""
# --> 556     future = self._workers.submit(SafeFunction(func))
#     557     future.get = functools.partial(self.wrap_future_result, future)
#     558     if callback is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/reusable_executor.py:176, in _ReusablePoolExecutor.submit(self, fn, *args, **kwargs)
#     174 def submit(self, fn, *args, **kwargs):
#     175     with self._submit_resize_lock:
# --> 176         return super().submit(fn, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:1149, in ProcessPoolExecutor.submit(self, fn, *args, **kwargs)
#    1146 # Wake up queue management thread
#    1147 self._executor_manager_thread_wakeup.wakeup()
# -> 1149 self._ensure_executor_running()
#    1150 return f
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:1123, in ProcessPoolExecutor._ensure_executor_running(self)
#    1121 with self._processes_management_lock:
#    1122     if len(self._processes) != self._max_workers:
# -> 1123         self._adjust_process_count()
#    1124     self._start_executor_manager_thread()
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:1111, in ProcessPoolExecutor._adjust_process_count(self)
#    1109         p = self._context.Process(target=_process_worker, args=args)
#    1110     p._worker_exit_lock = worker_exit_lock
# -> 1111     p.start()
#    1112     self._processes[p.pid] = p
#    1113 mp.util.debug(
#    1114     f"Adjusted process count to {self._max_workers}: "
#    1115     f"{[(p.name, pid) for pid, p in self._processes.items()]}"
#    1116 )
#
# File ~/anaconda3/lib/python3.11/multiprocessing/process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/process.py:32, in LokyProcess._Popen(process_obj)
#      30 else:
#      31     from .popen_loky_posix import Popen
# ---> 32 return Popen(process_obj)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py:46, in Popen.__init__(self, process_obj)
#      44 self.returncode = None
#      45 self._fds = []
# ---> 46 self._launch(process_obj)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/popen_loky_posix.py:97, in Popen._launch(self, process_obj)
#      95 set_spawning_popen(self)
#      96 try:
# ---> 97     prep_data = spawn.get_preparation_data(
#      98         process_obj._name,
#      99         getattr(process_obj, "init_main_module", True))
#     100     reduction.dump(prep_data, fp)
#     101     reduction.dump(process_obj, fp)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/backend/spawn.py:64, in get_preparation_data(name, init_main_module)
#      54 '''
#      55 Return info about parent needed by child to unpickle process object
#      56 '''
#      57 _check_not_importing_main()
#      58 d = dict(
#      59     log_to_stderr=util._log_to_stderr,
#      60     authkey=bytes(process.current_process().authkey),
#      61     name=name,
#      62     sys_argv=sys.argv,
#      63     orig_dir=process.ORIGINAL_DIR,
# ---> 64     dir=os.getcwd()
#      65 )
#      67 # Send sys_path and make sure the current directory will not be changed
#      68 d['sys_path'] = [p if p != '' else process.ORIGINAL_DIR for p in sys.path]
#
# FileNotFoundError: [Errno 2] No such file or directory
